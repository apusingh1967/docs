# %%
from io import BytesIO
import tarfile
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
url = './cal_housing.tgz'
tar = tarfile.open(url)
fpath = 'CaliforniaHousing/cal_housing.data'
fl = tar.extractfile(fpath)
arr = np.genfromtxt(fl, delimiter=',')
y = arr[:, -1]
pop, age = arr[:, [4, 7]].T
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-d32ffc15fba1> in <module>
#       5 arr = np.genfromtxt(fl, delimiter=',')
#       6 y = arr[:, -1]
# ----> 7 pop, age = arr[:, [4, 7]]
#       8 pop
#
# ValueError: too many values to unpack (expected 2)

# %%
def add_titlebox(ax, text):
    ax.text(.55, .8, text, 
            horizontalalignment='center',
           transform=ax.transAxes,
           bbox=dict(facecolor='white', alpha=.6),
           fontsize=12)
    return ax

# %%
gridsize = (3, 2)
fig = plt.figure(figsize=(12, 8))
ax1 = plt.subplot2grid(gridsize, (0, 0), colspan=2, rowspan=2)
ax2 = plt.subplot2grid(gridsize, (2, 0))
ax3 = plt.subplot2grid(gridsize, (2, 1))

ax1.set_title('Home val as fn of home ag and pop', fontsize=14)
sctr = ax1.scatter(x=age, y=pop, c=y, cmap='RdYlGn')
plt.colorbar(sctr, ax=ax1, format='$%d')
ax1.set_yscale('log')
ax2.hist(age, bins='auto')
ax3.hist(pop, bins='auto', log=True)

plt.show()

# %%
x = np.diag(np.arange(2, 5))[::-1]
x
# Out:
# array([[0, 0, 4],
#        [0, 3, 0],
#        [2, 0, 0]])
